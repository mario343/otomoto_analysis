# %%
import json
import re
import pandas as pd
import urllib
from urllib.request import Request
from bs4 import BeautifulSoup

# %%
url = "https://www.otomoto.pl/osobowe?page="

pages = []
for page_number in range(1, 10):
    print(f'Pobieranie strony {page_number}')
    with urllib.request.urlopen(f'{url}{page_number}') as resp:
        processed_page = BeautifulSoup(resp.read().decode('utf-8'), "html.parser")
        pages.append(processed_page)
# Out:
# Pobieranie strony 1
# Pobieranie strony 2
# Pobieranie strony 3
# Pobieranie strony 4
# Pobieranie strony 5
# Pobieranie strony 6
# Pobieranie strony 7
# Pobieranie strony 8
# Pobieranie strony 9

# %%
print(pages[1].prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="OTOMOTO - nowe i używane samochody i motocykle w Polska" name="description"/>
#   <meta content="1563466353912532" property="fb:app_id"/>
#   <meta content="OTOMOTO - nowe i używane samochody i motocykle w Polska" property="og:description"/>
#   <meta content="https://www.otomoto.pl/osobowe?page=2" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="//statics.otomoto.pl/optimus-storage/a/otomotopl/images/fb-image200x200.png" property="og:image"/>
#   <meta content="otomoto.pl" property="og:site_name"/>
#   <meta content="444086109" property="al:ios:app_store_id"/>
#   <meta content="Otomoto" property="al:ios:app_name"/>
#   <meta content="otomoto.pl://otomoto.pl/osobowe?page=2" property="al:ios:url"/>
#   <meta content="Otomoto" property="al:android:app_name"/>
# ...

# %%
# lista naszych województw
## TODO ##
list_of_voivodeships = []

## use this https://colab.research.google.com/drive/14r9PjCang--K5B1VI1Js3ENjVT221Yk3#scrollTo=AT9vw1H9374j

# start = "in "
# end = " 2022"
# for page in pages:
#   if re.search('%s(.*)%s' % (start, end), page.find("title").text) is not None:
#     list_of_voivodeships.append(re.search('%s(.*)%s' % (start, end), page.find("title").text).group(1))

# list_of_voivodeships

# %%
## TODO ##
# listt = []

# for page in pages:
#       listt = listt + page.find_all('div', class_='salaryblock floatedsalary shadow-light')

# print(len(listt))

# %%
## TODO ##
#lista miejscowosci w ktorych sa ogloszenia
# list_of_cities = []

# start = "in "
# end = " 2022"
# for page in pages:
#   if re.search('%s(.*)%s' % (start, end), page.find("title").text) is not None:
#     list_of_voivodeships.append(re.search('%s(.*)%s' % (start, end), page.find("title").text).group(1))

# list_of_cities

# %%
## TODO ##
#might be usefull

# yachts_data = []
# for yacht_html in full_yacht_data:
#     yacht = {}
#     yacht['name'] = yacht_html.find(class_="yacht-box__name").text.strip()
#     yacht['price'] = float(yacht_html.find(class_="price").span.contents[0].replace(' ', '').replace('PLN', '').replace(',', '.'))
#     yacht['img'] = f"https://zegluj.pl{yacht_html.img['src']}"
#     yacht['url'] = f"https://zegluj.pl{yacht_html.find(class_='yacht-box__image').a['href']}"
#     # parameters
#     for param_row in yacht_html.select('li.yacht-box-info__item'):
#         param_data = param_row.find_all('div')
#         param_type = param_data[0].text.strip()
#         param_value = re.sub(r'\s+', '', param_data[1].text.strip())
#         if 'osób' in param_type:
#             yacht['people'] = param_value
#         elif 'kabin' in param_type:
#             yacht['cabins'] = param_value
#         elif 'produkcji' in param_type:
#             yacht['year'] = param_value

#     yachts_data.append(yacht)
