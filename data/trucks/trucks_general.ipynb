# %%
import json
import re
import pandas as pd
import urllib
from urllib.request import Request
from bs4 import BeautifulSoup

# %%
url = "https://www.otomoto.pl/ciezarowe?page="

pages = []
for page_number in range(1, 408):
    print(f'Pobieranie strony {page_number}')
    with urllib.request.urlopen(f'{url}{page_number}') as resp:
        processed_page = BeautifulSoup(resp.read().decode('utf-8'), "html.parser")
        pages.append(processed_page)
# Out:
# Pobieranie strony 1
# Pobieranie strony 2
# Pobieranie strony 3
# Pobieranie strony 4
# Pobieranie strony 5
# Pobieranie strony 6
# Pobieranie strony 7
# Pobieranie strony 8
# Pobieranie strony 9
# Pobieranie strony 10
# Pobieranie strony 11
# Pobieranie strony 12
# Pobieranie strony 13
# Pobieranie strony 14
# Pobieranie strony 15
# Pobieranie strony 16
# Pobieranie strony 17
# Pobieranie strony 18
# Pobieranie strony 19
# Pobieranie strony 20
# Pobieranie strony 21
# Pobieranie strony 22
# Pobieranie strony 23
# Pobieranie strony 24
# Pobieranie strony 25
# Pobieranie strony 26
# Pobieranie strony 27
# Pobieranie strony 28
# Pobieranie strony 29
# Pobieranie strony 30
# Pobieranie strony 31
# Pobieranie strony 32
# Pobieranie strony 33
# Pobieranie strony 34
# Pobieranie strony 35
# Pobieranie strony 36
# Pobieranie strony 37
# Pobieranie strony 38
# Pobieranie strony 39
# Pobieranie strony 40
# Pobieranie strony 41
# Pobieranie strony 42
# Pobieranie strony 43
# ...

# %%
print(pages[0].prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="pl">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="OTOMOTO - nowe i używane samochody i motocykle w Polska" name="description"/>
#   <meta content="1563466353912532" property="fb:app_id"/>
#   <meta content="OTOMOTO - nowe i używane samochody i motocykle w Polska" property="og:description"/>
#   <meta content="https://www.otomoto.pl/ciezarowe?page=1" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="//statics.otomoto.pl/optimus-storage/a/otomotopl/images/fb-image200x200.png" property="og:image"/>
#   <meta content="otomoto.pl" property="og:site_name"/>
#   <meta content="444086109" property="al:ios:app_store_id"/>
#   <meta content="Otomoto" property="al:ios:app_name"/>
#   <meta content="otomoto.pl://otomoto.pl/ciezarowe?page=1" property="al:ios:url"/>
#   <meta content="Otomoto" property="al:android:app_name"/>
# ...

# %%
general_truck_data = []
for page in pages:
     general_truck_data += page.find_all('article', attrs={'class': lambda c: c.startswith('ooa'), 'data-testid': 'listing-ad'})

print(len(general_truck_data))  
print(general_truck_data[0])
# Out:
# 13000
# ...

# %%
list_of_voivodeships = []
for page in pages:
    spans = page.find_all('span', class_='ooa-fzu03x')
    for span in spans:
        voivodeship = span.contents[4].strip()
        list_of_voivodeships.append(voivodeship)

#tutaj mamy listę wszystkich ogłoszeń, czyli mozemy sobie z tego
#wyciągnać liste wszystkich ogloszen wedlug wojewodztwa


#tutaj robimy unikalne
unique_voivodeships = list(set(list_of_voivodeships))
print(unique_voivodeships)
print(len(unique_voivodeships))

print("Unikalne wojewodztwa lacznie")
#print(list_of_voivodeships)
print(len(list_of_voivodeships))
# Out:
# ['Wielkopolskie', 'Kujawsko-pomorskie', 'Małopolskie', 'Zachodniopomorskie', 'Tarragona', 'Dolnośląskie', 'Podkarpackie', 'Łódzkie', 'Languedoc-Roussillon-Midi-Pyrénées', 'Hallands län', 'Rheinland-Pfalz', 'Śląskie', 'Kowno', 'Koszyce', 'Wilno', 'Holandia', 'Comunidad de Madrid', 'Nordrhein-Westfalen', 'Podlaskie', 'Region Syddanmark', 'Świętokrzyskie', 'Lubelskie', 'Lubuskie', 'Saarland', 'Mazowieckie', 'Pomorskie', 'Warmińsko-mazurskie', 'Nitra', 'Opolskie']
# 29
# Unikalne wojewodztwa lacznie
# 13000

# %%
list_of_cities = []
for page in pages:
    spans = page.find_all('span', class_='ooa-fzu03x')
    for span in spans:
        city = span.contents[0].strip()
        list_of_cities.append(city)

#tutaj mamy listę wszystkich ogłoszeń, czyli mozemy sobie z tego
#wyciągnać liste wszystkich ogloszen wedlug miejscowosci

#tutaj robimy unikalne
unique_cities = list(set(list_of_cities))
print(unique_cities)
print("Unikalne miasta łącznie")
print(len(unique_cities))

#print(list_of_cities)
print("Wszystkie miasta łącznie")
print(len(list_of_cities))
# Out:
# ['Mirachowo', 'Chełm Śląski', 'Mława', 'Mirosławice', 'Łubienica', 'Brzezie', 'Raciechowice', 'Ślesin', 'Szklarka Myślniewska', 'Żerniki', 'Chełmno', 'Osiecznica', 'Radlin', 'Nekla', 'Jawornik', 'Kostomłoty', 'Barlinek', 'Warszawa', 'Rzgów', 'Kaunas', 'Torzym', 'Woźniki', 'Barszczówka', 'Niedźwiedź', 'Góra', 'Myślenice', 'Pawłów', 'Wisznice', 'Rzepedź', 'Ciechocinek', 'Mleczków', 'Opatów', 'Rybarzowice', 'Solec Kujawski', 'Skrzyńsko', 'Chełmiec', 'Śmigiel', 'Ławki', 'Kopanica', 'Nidzica', 'Janinów', 'Tychowo', 'Czaplinek', 'Nowe Iganie', 'Mykanów', 'Przyłubie', 'Zwoleń', 'Garby', 'Trzebownisko', 'Biała', 'Łapanów', 'Sława', 'Raciszyn', 'Tarnowiec', 'Witaszyce', 'Wartowice', 'Chynów', 'Głowno', 'Witunia', 'Bełżyce', 'Ropczyce', 'Łowoszów', 'Bystrzyca Kłodzka', 'Łuszczów Pierwszy', 'Malbork', 'Czarlin', 'Ogrodzieniec', 'Kalisz Pomorski', 'Złotniki', 'Kęty', 'Goniądz', 'Pszczyna', 'Dobrcz', 'Bierzglinek', 'Olszówka', 'Budzisław Kościelny', 'Janów', 'Michałów-Reginów', 'Wola Pękoszewska'
# ...

# %%
truck_names = []

motorbikes_elements = pages[0].find_all('em')
for motorbike_element in motorbikes_elements:
    motorbike_name = motorbike_element.get_text(strip=True)
    truck_names.append(motorbike_name)

unique_truck_names = list(set(truck_names))
unique_truck_names = [car for car in  list(set(truck_names)) if car not in list_of_voivodeships]
print(unique_truck_names)
# Out:
# ['Peugeot', 'Kamaz', 'FUSO', 'Fiat', 'Ford', 'Terberg', 'Steyr', 'Inny', 'Temsa', 'Schmitz', 'Volkswagen', 'Autosan', 'Scania', 'Setra', 'Nissan', 'Volvo', 'DAF', 'Mercedes-Benz', 'Tatra', 'Irisbus', 'Iveco', 'Renault', 'Isuzu', 'MAN', 'Mitsubishi', 'Krone', 'Citroën', 'Bova', 'Star']

# %%
truck_info = []

for i in range(1,13000):
    #print(general_delivery_car_data[i])
    
    name_element = general_truck_data[i].find('h2', class_='evg565y6')
    
    if name_element is None:
        continue  # Skip this iteration if name element is not found
    
    name = name_element.text.strip()
    model = ''
    
    for unique_name in unique_truck_names:
        if unique_name in name:
            model = name.replace(unique_name, '').strip()
            name = unique_name
            break
    # Extracting price
    price_element = general_truck_data[i].find('div', class_='evg565y12')
    
    if price_element is None:
        continue  # Skip this iteration if price element is not found
    
    price = price_element.text.strip()
    
    # Extracting city and voivodeship
    location_element = general_truck_data[i].find('span', class_='ooa-1ammnlq')
    
    if location_element is None:
        continue  # Skip this iteration if location element is not found
    
    city_element = location_element.find('span', class_='ooa-fzu03x')
    
    if city_element is None:
        continue  # Skip this iteration if city element is not found
    
    city = city_element.text.strip().split('(')[0].strip()
    voivodeship = city_element.text.strip().split('(')[1].strip().strip(')')
    
    # Extracting production year, mileage, engine capacity, and engine type
    details = general_truck_data[i].find_all('li', class_='ooa-1k7nwcr')
    
    if len(details) < 4:
        continue  # Skip this iteration if details are incomplete
    
    production_year = details[0].text.strip()
    mileage = details[1].text.strip()
    engine_capacity = details[2].text.strip()
    engine_type = details[3].text.strip()
    
    # Creating a dictionary for the current car offer
    car_offer = {
        'Name': name,
        'Model': model,  # do zrobienia z Name
        'Price': price,
        'City': city,
        'Voivodeship': voivodeship,
        'Production Year': production_year,
        'Mileage': mileage,
        'Engine Type': engine_type,
        'Engine Capacity': engine_capacity
    }
    
    # Adding the car offer to the delivery_car_data array
    truck_info.append(car_offer)
print(len(truck_info))
# Out:
# 12973

# %%
frame = pd.DataFrame.from_dict(truck_info)
frame
# Out:
#                 Name                                              Model  \
# 0      Mercedes-Benz                                        ATEGO 1329L
# 1                MAN                   TGX 18.460 BLS Standard/Retarder
# 2             Scania                                            R450 NG
# 3              Iveco  Eurocargo 120E21 E6 HDS / Wywrotka / Bortmatic...
# 4                DAF                                  CF460 ATLAS 170.2
# ...              ...                                                ...
# 12968         Scania                                    R410 STREAMLINE
# 12969  Mercedes-Benz                                             Actros
# 12970            DAF                                         XF.105.410
# 12971         Scania                                               R420
# 12972          Volvo                                                 FH
#
#              Price             City    Voivodeship Production Year  \
# ...

# %%
import csv
filename = 'truck_info.csv'

with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = [
        'Name',
        'Model',
        'Price',
        'City',
        'Voivodeship',
        'Production Year',
        'Mileage',
        'Engine Type',
        'Engine Capacity'
    ]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()  # Write the header row
    
    for truck_offer in truck_info:
        writer.writerow(truck_offer)
    
print(f"Data saved to {filename} successfully.")
# Out:
# Data saved to truck_info.csv successfully.
